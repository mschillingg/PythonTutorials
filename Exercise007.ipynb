# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read .csv file

# %%
myDataFromFile = pd.read_csv("datasets/007ExerciseFile.csv")

# %%
display(myDataFromFile)
# Out:
#        Strain  Mutation_rate
# 0    st_alpha      10.612005
# 1    st_alpha      12.586371
# 2    st_alpha       8.997583
# 3    st_alpha      11.681775
# 4    st_alpha      14.408237
# ..        ...            ...
# 163  st_delta       2.716249
# 164  st_delta       2.467378
# 165  st_delta       2.119801
# 166  st_delta       1.316537
# 167  st_delta       2.060472
#
# [168 rows x 2 columns]

# %% [markdown]
# ### Histogram

# %%
sns.displot(myDataFromFile, x="Mutation_rate", hue="Strain", kind="hist", bins=50, alpha=0.3)

# %% [markdown]
# ### KDE plot

# %%
sns.displot(myDataFromFile, x="Mutation_rate", hue="Strain", kind="kde")

# %%
sns.displot(myDataFromFile, x="Mutation_rate", hue="Strain", kind="kde", fill=True, alpha=0.2)

# %% [markdown]
# ### Violin plot

# %%
sns.violinplot(data=myDataFromFile, x="Mutation_rate", y="Strain")
# Out:
# <AxesSubplot:xlabel='Mutation_rate', ylabel='Strain'>

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(data=myDataFromFile, x="Mutation_rate", y="Strain")
# Out:
# <AxesSubplot:xlabel='Mutation_rate', ylabel='Strain'>

# %% [markdown]
# ### Boxplot with overlaid strip plot

# %%
sns.boxplot(data=myDataFromFile, x="Mutation_rate", y="Strain")
sns.stripplot(data=myDataFromFile, x="Mutation_rate", y="Strain", alpha = 0.4)
# Out:
# <AxesSubplot:xlabel='Mutation_rate', ylabel='Strain'>

# %% [markdown]
# ## Dr. Fauci, I present to you the Boxplot with Overlaid Strip Plot:

# %%
sns.boxplot(data=myDataFromFile, x="Mutation_rate", y="Strain")
sns.stripplot(data=myDataFromFile, x="Mutation_rate", y="Strain", alpha = 0.3)
plt.xlabel("Mutation Rate")
y=[0,1,2,3]
labels=["Delta","Gamma","Beta","Alpha"]
plt.yticks(y, labels)
# Out:
# ([<matplotlib.axis.YTick at 0x7ff0be8cadf0>,
# ...
#  [Text(0, 0, 'Delta'),
#   Text(0, 1, 'Gamma'),
#   Text(0, 2, 'Beta'),
#   Text(0, 3, 'Alpha')])

# %% [markdown]
# ### This plot gives a nice visualization of the data–the distance between the median lines on each of the boxes highlights the significant differences between the mutation rates of each of the strains.
