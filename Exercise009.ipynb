# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.load('datasets/009ExerciseFile2.npy')

# %%
plt.plot(data[4, :])

# %%
plt.plot(data[0:20, :]);

# %%
plt.plot(data[:,:]);

# %%
plt.plot(data[60, :])

# %%
plt.plot(data[12:20, :]);

# %%
plt.plot(data[12:20,5:10]);

# %%
plt.plot(data.sum(0)); #column sum

# %%
plt.plot(data.sum(1)); #row sum

# %%
#making a pretty plot
plt.plot(data.sum(1), color="red");
plt.title("Averages of Columns by Row")
plt.ylabel("Average")
plt.xlabel("Row Number")
# Out:
# Text(0.5, 0, 'Row Number')

# %% [markdown]
# ### This is a bimodal pattern of our data
